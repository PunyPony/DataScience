# %% [markdown]
# EPITA 2019 MLRF practice_04-01_BoVW v2019-05-27_171311 by Joseph CHAZALON
#
# <div style="overflow: auto; padding: 10px; margin: 10px 0px">
# <img alt="Creative Commons License" src='img/CC-BY-4.0.png' style='float: left; margin-right: 20px'>
#
# This work is licensed under a [Creative Commons Attribution 4.0 International License](http://creativecommons.org/licenses/by/4.0/).
# </div>

# %% [markdown]
# # Practice 04 part 01: Bag of Visual Words search engine
#
# We will demonstrate how to use this classical technique to build a global descriptor from local descriptors.
#
# In this session, you will learn how to produce results like the ones displayed below (left column: queries, other columns: responses to query in the same row).
#
# ![Sample output](img/practice_04/sample_results.jpg)
#
#
# We will proceed in 9 steps:
#
# 1. Sample some descriptors for codebook learning
# 2. Learn normalisation parameters for descriptors (mean and eigenvectors)
# 3. Use k-Means to learn a codebook
# 4. Compute the BoVW vector for each image
# 5. Setup a nearest neighbors search structure
# 6. Evaluate our approach using mean average precision
# 7. Display some results
# 8. Compute the best results for the test queries
# 9. Export the results for the test queries (and submit them for grading).
#
#
# ## Resources
# The resources for this session are stored on the network.
# Here is a summary of the files we provide:
# - `jpg/*.jpg`: 1491 images;
# - `thumbs/*.jpg`: image thumbnails for fast display;
# - `siftgeo/*.siftgeo`: associated pre-computed SIFT descriptors for each image;
# - `gt_student.json`: a partial ground truth to enable a partial evaluation of the retrieval;
# - `queries_for_grading.json`: a list of queries for which you need to submit your results.
#
#
# ## Ground truth format
# The ground truth file is a JSON file. Here is an except:
# ```json
# {
#  "90314": [
#   "90989",
#   "91259"
#  ],
#  "90376": [
#   "90674"
#  ],
#  ...
# }
# ```
# It contains a dictionary which associated to each query the list of relevant elements.
# Every value is a string representing an image identifier, ie the part of the image or descriptor file without extension.
#
# Example: `"90314"` is the identifier
# of the image `jpgs/90314.jpg`
# with descriptors available at `siftgeo/90314.siftgeo`
# and its thumbnail is `thumbs/90314.jpg`.
#
# Looking at the previous excerpt, we can see that the query `90314` has two relevant results: `90989` and `91259`.
#
#
# ## Local descriptors
# We provide precomputed SIFT descriptors to save you time.
# We also provide a commodity function to help you loading them (see below).

# %% [markdown]
# ## 0. Import module, load resources

# %%
# deactivate buggy jupyter completion
# %config Completer.use_jedi = False

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
# setup the resources location
PATH_TO_RESOURCES = "/afs/cri.epita.net/resources/teach/bigdata/mlrf19/resources/INRIA_Holidays_shuffled"

# %% [markdown]
# ## Code to read descriptors
# We provide you with the `siftgeo_read_desc(path)` which allows to get the array of descriptors stored in a `.siftgeo` file.

# %%
SIFTGEO_DTYPE = np.dtype([
    ("x", "<f4"),
    ("y", "<f4"),
    ("scale", "<f4"),
    ("angle", "<f4"),
    ("mi11", "<f4"),
    ("mi12", "<f4"),
    ("mi21", "<f4"),
    ("mi22", "<f4"),
    ("cornerness", "<f4"),
    ("desdim", "<i4"),
    ("component", "<u1", 128)
])

def siftgeo_read_full(path):
    return np.fromfile(path, dtype=SIFTGEO_DTYPE)

def siftgeo_read_desc(path):
    desc = siftgeo_read_full(path)["component"]
    if desc.size == 0: 
        desc = np.zeros((0, 128), dtype = 'uint8')
    return desc

# %% [markdown]
# ## Some of utility listings
# Again, to save you time, here are some useful lists and mappings:
# - `IMG_NAMES_FULL`: list of all full images paths
# - `IMG_IDS`: list of image ids (filename without directories nor extension)
# - `imgid_to_index`: a mapping from image ids (like `'90000'`, `'90001'`, `'90002'` or `'90003'` — note the quotes indicating string types) to an absolute index in the image list (like `0`, `1`, `2` or `3` — integers). **This will be useful to convert between image paths and rows in the global index.**

# %%
IMG_NAMES_FULL = !ls $PATH_TO_RESOURCES/jpg/*.jpg | sort
len(IMG_NAMES_FULL), IMG_NAMES_FULL[:5]
# Out:
# (1491,
#  ['/afs/cri.epita.net/resources/teach/bigdata/mlrf19/resources/INRIA_Holidays_shuffled/jpg/90000.jpg',
#   '/afs/cri.epita.net/resources/teach/bigdata/mlrf19/resources/INRIA_Holidays_shuffled/jpg/90001.jpg',
#   '/afs/cri.epita.net/resources/teach/bigdata/mlrf19/resources/INRIA_Holidays_shuffled/jpg/90002.jpg',
#   '/afs/cri.epita.net/resources/teach/bigdata/mlrf19/resources/INRIA_Holidays_shuffled/jpg/90003.jpg',
#   '/afs/cri.epita.net/resources/teach/bigdata/mlrf19/resources/INRIA_Holidays_shuffled/jpg/90004.jpg'])

# %%
IMG_IDS = [p.split('/')[-1][:-4] for p in IMG_NAMES_FULL]
len(IMG_IDS), IMG_IDS[:5]
# Out:
# (1491, ['90000', '90001', '90002', '90003', '90004'])

# %%
imgid_to_index = {imgid: ii for ii, imgid in enumerate(IMG_IDS)}
imgid_to_index
# Out:
# {'90000': 0,
#  '90001': 1,
#  '90002': 2,
#  '90003': 3,
#  '90004': 4,
#  '90005': 5,
#  '90006': 6,
#  '90007': 7,
#  '90008': 8,
#  '90009': 9,
#  '90010': 10,
#  '90011': 11,
#  '90012': 12,
#  '90013': 13,
#  '90014': 14,
#  '90015': 15,
#  '90016': 16,
#  '90017': 17,
#  '90018': 18,
#  '90019': 19,
#  '90020': 20,
#  '90021': 21,
#  '90022': 22,
#  '90023': 23,
#  '90024': 24,
#  '90025': 25,
#  '90026': 26,
#  '90027': 27,
#  '90028': 28,
#  '90029': 29,
#  '90030': 30,
#  '90031': 31,
#  '90032': 32,
#  '90033': 33,
#  '90034': 34,
#  '90035': 35,
#  '90036': 36,
#  '90037': 37,
#  '90038': 38,
#  '90039': 39,
#  '90040': 40,
#  '90041': 41,
#  '90042': 42,
#  '90043': 43,
#  '90044': 44,
#  '90045': 45,
#  '90046': 46,
#  '90047': 47,
#  '90048': 48,
#  '90049': 49,
#  '90050': 50,
#  '90051': 51,
#  '90052': 52,
#  '90053': 53,
#  '90054': 54,
#  '90055': 55,
#  '90056': 56,
#  '90057': 57,
#  '90058': 58,
#  '90059': 59,
#  '90060': 60,
#  '90061': 61,
#  '90062': 62,
#  '90063': 63,
#  '90064': 64,
#  '90065': 65,
#  '90066': 66,
#  '90067': 67,
#  '90068': 68,
#  '90069': 69,
#  '90070': 70,
#  '90071': 71,
#  '90072': 72,
#  '90073': 73,
#  '90074': 74,
#  '90075': 75,
#  '90076': 76,
#  '90077': 77,
#  '90078': 78,
#  '90079': 79,
#  '90080': 80,
#  '90081': 81,
#  '90082': 82,
#  '90083': 83,
#  '90084': 84,
# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Randomly select 100 images and load the descriptors from those images. We will call those descriptors `train_desc`.**
# </div>

# %%
# TODO sample some images
np.random.seed(0)
sample_image_ID = np.random.choice(IMG_IDS, 100)
#sample_image_ids = np.random.choice(IMG_IDS, 100)
assert(len(sample_image_ID)==100)

train_desc = np.array([siftgeo_read_desc(os.path.join(PATH_TO_RESOURCES,'siftgeo',imageID+".siftgeo")) for imageID in sample_image_ID])

# %% [markdown]
# ### 1.2 Prepare those descriptors for training
# For those descriptors to be helpful, we need them to be staked in a big single array of shape `(num_desc, desc_len)` where `desc_len` is the length of a single descriptor — here 128 because SIFT decriptors are vectors of 128 integers.

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Turn your list of arrays of descriptors in a big single array. Its shape should be something like `(314302, 128)`.**
# </div>

# %%
# stack all you descriptors into one big array
train_desc = np.concatenate(train_desc)
train_desc.shape, train_desc.dtype
# Out:
# ((307213, 128), dtype('uint8'))

# %% [markdown]
# Finally, we convert this array to float32 elements to avoid normalization issues.

# %%
train_desc = train_desc.astype(np.float32)

# %% [markdown]
# ## 2. Learn normalisation parameters for descriptors
# Before learning a codebook, it is a good practice to:
# - center the features;
# - reduce their dimension using PCA.
#
# **Warning**: We do NOT REDUCE (divide by the variance) the descriptors here because we want to keep the relative value of the variables. This is indeed the very purpose of histograms!
#
# **This is a first learning step!** Because we will compute a **mean** and **eigenvectors** on a **training set**, we need to **store those values** in order to be able to apply them to test elements later.

# %% [markdown]
# ### 2.1 Centering descriptors

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Compute and store the mean of your descriptors, then center them.**
# </div>

# %%
# compute mean and center descriptors
train_mean = np.mean(train_desc, axis=1)
train_desc = np.apply_along_axis(lambda desc : desc - np.mean(desc), 1, train_desc)

# %%
# compute SVD matrix and keep only 64 dimensions
from sklearn.decomposition import TruncatedSVD
from sklearn.random_projection import sparse_random_matrix

svd_transform = TruncatedSVD(n_components=64, n_iter=7, random_state=0)
train_desc = svd_transform.fit_transform(train_desc).reshape(-1,64)

# %% [markdown]
# ### 2.2 PCA
# We will now compute the PCA parameters which will allow us to reduce the dimension of our descriptors from 128 floats to 64 floats, keeping as much information as possible.

# %%
# # compute PCA matrix and keep only 64 dimensions
# train_cov = np.dot(train_desc.T, train_desc)
# eigvals, eigvecs = np.linalg.eig(train_cov)
# perm = eigvals.argsort()                   # sort by increasing eigenvalue
# plt.plot(eigvals) #64 semble être un bon nombre
# pca_transform = eigvecs[:, perm[64:128]]   # eigenvectors for the 64 last eigenvalues
# pca_transform.shape, pca_transform.dtype

# # transform sample with PCA (note that numpy imposes line-vectors,
# # so we right-multiply the vectors)
# train_desc = np.dot(train_desc, pca_transform)

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Apply the PCA transformation to your descriptors.**
# </div>

# %%
# Check the shape of your new descriptors: we expect a shape like (BIGNUMBER, 64)
train_desc.shape
# Out:
# (307213, 64)

# %% [markdown]
# ## 3. Use k-Means to learn a codebook
# We are now ready to learn a codebook using those centered and compact descriptors.
# We will use exactly the same technique as the one we used to compute color histograms:
# - first we fit a k-Means;
# - then, using the centroids we found, we will project the descriptors and compute bag of features for each image.

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Fit a k-Means with 512 clusters on the training descriptors.**
# </div>

# %%
# fit a k-means
#kmeans = KMeans(n_clusters=512, random_state=0).fit(train_desc)
kmeans = MiniBatchKMeans(n_clusters=512, random_state=0).fit(train_desc)
# Out:
# /usr/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1558: RuntimeWarning: init_size=300 should be larger than k=512. Setting it to 3*k
#   init_size=init_size)
# /usr/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1558: RuntimeWarning: init_size=300 should be larger than k=512. Setting it to 3*k
#   init_size=init_size)
# /usr/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:1558: RuntimeWarning: init_size=300 should be larger than k=512. Setting it to 3*k
#   init_size=init_size)

# %%
# let's check the shape of the cluster's centers
kmeans.cluster_centers_.shape
# Out:
# (512, 64)

# %% [markdown]
# We expect a shape of `(512, 64)` for cluster centers: we have 512 clusters in a 64-dimensional space.

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **How do we call this set of cluster centers? They define the set of possible descriptor values we will use to build bag of visual words descriptors. Write down your answer.**
# </div>

# %% [markdown]
# TODO
# We call this set of cluster centers ...

# %% [markdown]
# ## 4. Compute the BoVW vector for each image
# Using the codebook we just learned, we will compute for each image its bag of features vector (histogram of projected descriptors).
#
# It is almost exaclty like the color histogram we computed in practice session 2!
# The **only** different is that we have much more dimensions.
#
# We will put those descriptors in a naive index made of a single NumPy array.

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **For each image, compute its BoVW vector.**
# </div>
#
# **Beware:**
# - in a few images no descriptor was extracted so you need to skip those elements
# - you need to apply the same preprocessings than the ones you applied to training descriptors

# %%
# TODO index all images
import os

# Here is our very simple index
global_image_descr = np.zeros((len(IMG_IDS), kmeans.n_clusters), dtype=np.float32)

#print(global_image_descr.shape)

for ii, imgid in enumerate(IMG_IDS):
    print("Indexing %s" % (imgid,))
    # read the descriptors
    image_path = os.path.join(PATH_TO_RESOURCES,'siftgeo',imgid+".siftgeo")
    desc = siftgeo_read_full(image_path)["component"]
    
    # handle case where no descriptor is available
    if desc.size==0:
        continue
    # apply the same preprocessing as for training descriptors
    desc = desc - np.mean(desc)
    #pca
    #desc_in_newbase = desc@pca_transform
    
    desc_in_newbase = svd_transform.transform(desc)

    # get cluster ids
    centers = kmeans.predict(desc_in_newbase)
    #print(centers)
    
    # compute histogram
    descr_hist, _ = np.histogram(centers, bins=np.arange(kmeans.n_clusters+1))
    #descr_hist, bin_edges = np.histogram(centers, bins=512)
    #print(descr_hist)
    # update the index
    global_image_descr[ii] = descr_hist


#tfidf
nb_pic_contains_f = np.zeros(kmeans.n_clusters)

for ii, imgid in enumerate(IMG_IDS):
    contains_f_index = np.where(global_image_descr[ii] != 0)[0]
    nb_pic_contains_f[contains_f_index] += 1

nb_pic_contains_f = np.where(nb_pic_contains_f== 0, nb_pic_contains_f+1, nb_pic_contains_f)
global_image_descr = np.apply_along_axis(lambda hist: hist/(hist.sum() if hist.sum() else 1) * np.log(len(IMG_IDS)/nb_pic_contains_f), 
                                         1, global_image_descr)
    

print("Indexing complete.")
global_image_descr.shape, global_image_descr.dtype
# Out:
# Indexing 90000
# Indexing 90001
# Indexing 90002
# Indexing 90003
# Indexing 90004
# Indexing 90005
# Indexing 90006
# Indexing 90007
# Indexing 90008
# Indexing 90009
# Indexing 90010
# Indexing 90011
# Indexing 90012
# Indexing 90013
# Indexing 90014
# Indexing 90015
# Indexing 90016
# Indexing 90017
# Indexing 90018
# Indexing 90019
# Indexing 90020
# Indexing 90021
# Indexing 90022
# Indexing 90023
# Indexing 90024
# Indexing 90025
# Indexing 90026
# Indexing 90027
# Indexing 90028
# Indexing 90029
# Indexing 90030
# Indexing 90031
# Indexing 90032
# Indexing 90033
# Indexing 90034
# Indexing 90035
# Indexing 90036
# Indexing 90037
# Indexing 90038
# Indexing 90039
# Indexing 90040
# Indexing 90041
# Indexing 90042
# Indexing 90043
# Indexing 90044
# Indexing 90045
# Indexing 90046
# Indexing 90047
# Indexing 90048
# Indexing 90049
# Indexing 90050
# Indexing 90051
# Indexing 90052
# Indexing 90053
# Indexing 90054
# Indexing 90055
# Indexing 90056
# Indexing 90057
# Indexing 90058
# Indexing 90059
# Indexing 90060
# Indexing 90061
# Indexing 90062
# Indexing 90063
# Indexing 90064
# Indexing 90065
# Indexing 90066
# Indexing 90067
# Indexing 90068
# Indexing 90069
# Indexing 90070
# Indexing 90071
# Indexing 90072
# Indexing 90073
# Indexing 90074
# Indexing 90075
# Indexing 90076
# Indexing 90077
# Indexing 90078
# Indexing 90079
# Indexing 90080
# Indexing 90081
# Indexing 90082
# Indexing 90083
# Indexing 90084
# Indexing 90085
# Indexing 90086
# Indexing 90087
# Indexing 90088
# Indexing 90089
# Indexing 90090
# Indexing 90091
# Indexing 90092
# Indexing 90093
# Indexing 90094
# Indexing 90095
# Indexing 90096
# Indexing 90097
# Indexing 90098
# Indexing 90099
# Indexing 90100
# Indexing 90101
# Indexing 90102
# Indexing 90103
# Indexing 90104
# Indexing 90105
# Indexing 90106
# Indexing 90107
# Indexing 90108
# Indexing 90109
# Indexing 90110
# Indexing 90111
# Indexing 90112
# Indexing 90113
# Indexing 90114
# Indexing 90115
# Indexing 90116
# Indexing 90117
# Indexing 90118
# Indexing 90119
# Indexing 90120
# Indexing 90121
# Indexing 90122
# Indexing 90123
# Indexing 90124
# Indexing 90125
# Indexing 90126
# Indexing 90127
# Indexing 90128
# Indexing 90129
# Indexing 90130
# Indexing 90131
# Indexing 90132
# Indexing 90133
# Indexing 90134
# Indexing 90135
# Indexing 90136
# Indexing 90137
# Indexing 90138
# Indexing 90139
# Indexing 90140
# Indexing 90141
# Indexing 90142
# Indexing 90143
# Indexing 90144
# Indexing 90145
# Indexing 90146
# Indexing 90147
# Indexing 90148
# Indexing 90149
# Indexing 90150
# Indexing 90151
# Indexing 90152
# Indexing 90153
# Indexing 90154
# Indexing 90155
# Indexing 90156
# Indexing 90157
# Indexing 90158
# Indexing 90159
# Indexing 90160
# Indexing 90161
# Indexing 90162
# Indexing 90163
# Indexing 90164
# Indexing 90165
# Indexing 90166
# Indexing 90167
# Indexing 90168
# Indexing 90169
# Indexing 90170
# Indexing 90171
# Indexing 90172
# Indexing 90173
# Indexing 90174
# Indexing 90175
# Indexing 90176
# Indexing 90177
# Indexing 90178
# Indexing 90179
# Indexing 90180
# Indexing 90181
# Indexing 90182
# Indexing 90183
# Indexing 90184
# Indexing 90185
# Indexing 90186
# Indexing 90187
# Indexing 90188
# Indexing 90189
# Indexing 90190
# Indexing 90191
# Indexing 90192
# Indexing 90193
# Indexing 90194
# Indexing 90195
# Indexing 90196
# Indexing 90197
# Indexing 90198
# Indexing 90199
# Indexing 90200
# Indexing 90201
# Indexing 90202
# Indexing 90203
# Indexing 90204
# Indexing 90205
# Indexing 90206
# Indexing 90207
# Indexing 90208
# Indexing 90209
# Indexing 90210
# Indexing 90211
# Indexing 90212
# Indexing 90213
# Indexing 90214
# Indexing 90215
# Indexing 90216
# Indexing 90217
# Indexing 90218
# Indexing 90219
# Indexing 90220
# Indexing 90221
# Indexing 90222
# Indexing 90223
# Indexing 90224
# Indexing 90225
# Indexing 90226
# Indexing 90227
# Indexing 90228
# Indexing 90229
# Indexing 90230
# Indexing 90231
# Indexing 90232
# Indexing 90233
# Indexing 90234
# Indexing 90235
# Indexing 90236
# Indexing 90237
# Indexing 90238
# Indexing 90239
# Indexing 90240
# Indexing 90241
# Indexing 90242
# Indexing 90243
# Indexing 90244
# Indexing 90245
# Indexing 90246
# Indexing 90247
# Indexing 90248
# Indexing 90249
# Indexing 90250
# Indexing 90251
# Indexing 90252
# Indexing 90253
# Indexing 90254
# Indexing 90255
# Indexing 90256
# Indexing 90257
# Indexing 90258
# Indexing 90259
# Indexing 90260
# Indexing 90261
# Indexing 90262
# Indexing 90263
# Indexing 90264
# Indexing 90265
# Indexing 90266
# Indexing 90267
# Indexing 90268
# Indexing 90269
# Indexing 90270
# Indexing 90271
# Indexing 90272
# Indexing 90273
# Indexing 90274
# Indexing 90275
# Indexing 90276
# Indexing 90277
# Indexing 90278
# Indexing 90279
# Indexing 90280
# Indexing 90281
# Indexing 90282
# Indexing 90283
# Indexing 90284
# Indexing 90285
# Indexing 90286
# Indexing 90287
# Indexing 90288
# Indexing 90289
# Indexing 90290
# Indexing 90291
# Indexing 90292
# Indexing 90293
# Indexing 90294
# Indexing 90295
# Indexing 90296
# Indexing 90297
# Indexing 90298
# Indexing 90299
# Indexing 90300
# Indexing 90301
# Indexing 90302
# Indexing 90303
# Indexing 90304
# Indexing 90305
# Indexing 90306
# Indexing 90307
# Indexing 90308
# Indexing 90309
# Indexing 90310
# Indexing 90311
# Indexing 90312
# Indexing 90313
# Indexing 90314
# Indexing 90315
# Indexing 90316
# Indexing 90317
# Indexing 90318
# Indexing 90319
# Indexing 90320
# Indexing 90321
# Indexing 90322
# Indexing 90323
# Indexing 90324
# Indexing 90325
# Indexing 90326
# Indexing 90327
# Indexing 90328
# Indexing 90329
# Indexing 90330
# Indexing 90331
# Indexing 90332
# Indexing 90333
# Indexing 90334
# Indexing 90335
# Indexing 90336
# Indexing 90337
# Indexing 90338
# Indexing 90339
# Indexing 90340
# Indexing 90341
# Indexing 90342
# Indexing 90343
# Indexing 90344
# Indexing 90345
# Indexing 90346
# Indexing 90347
# Indexing 90348
# Indexing 90349
# Indexing 90350
# Indexing 90351
# Indexing 90352
# Indexing 90353
# Indexing 90354
# Indexing 90355
# Indexing 90356
# Indexing 90357
# Indexing 90358
# Indexing 90359
# Indexing 90360
# Indexing 90361
# Indexing 90362
# Indexing 90363
# Indexing 90364
# Indexing 90365
# Indexing 90366
# Indexing 90367
# Indexing 90368
# Indexing 90369
# Indexing 90370
# Indexing 90371
# Indexing 90372
# Indexing 90373
# Indexing 90374
# Indexing 90375
# Indexing 90376
# Indexing 90377
# Indexing 90378
# Indexing 90379
# Indexing 90380
# Indexing 90381
# Indexing 90382
# Indexing 90383
# Indexing 90384
# Indexing 90385
# Indexing 90386
# Indexing 90387
# Indexing 90388
# Indexing 90389
# Indexing 90390
# Indexing 90391
# Indexing 90392
# Indexing 90393
# Indexing 90394
# Indexing 90395
# Indexing 90396
# Indexing 90397
# Indexing 90398
# Indexing 90399
# Indexing 90400
# Indexing 90401
# Indexing 90402
# Indexing 90403
# Indexing 90404
# Indexing 90405
# Indexing 90406
# Indexing 90407
# Indexing 90408
# Indexing 90409
# Indexing 90410
# Indexing 90411
# Indexing 90412
# Indexing 90413
# Indexing 90414
# Indexing 90415
# Indexing 90416
# Indexing 90417
# Indexing 90418
# Indexing 90419
# Indexing 90420
# Indexing 90421
# Indexing 90422
# Indexing 90423
# Indexing 90424
# Indexing 90425
# Indexing 90426
# Indexing 90427
# Indexing 90428
# Indexing 90429
# Indexing 90430
# Indexing 90431
# Indexing 90432
# Indexing 90433
# Indexing 90434
# Indexing 90435
# Indexing 90436
# Indexing 90437
# Indexing 90438
# Indexing 90439
# Indexing 90440
# Indexing 90441
# Indexing 90442
# Indexing 90443
# Indexing 90444
# Indexing 90445
# Indexing 90446
# Indexing 90447
# Indexing 90448
# Indexing 90449
# Indexing 90450
# Indexing 90451
# Indexing 90452
# Indexing 90453
# Indexing 90454
# Indexing 90455
# Indexing 90456
# Indexing 90457
# Indexing 90458
# Indexing 90459
# Indexing 90460
# Indexing 90461
# Indexing 90462
# Indexing 90463
# Indexing 90464
# Indexing 90465
# Indexing 90466
# Indexing 90467
# Indexing 90468
# Indexing 90469
# Indexing 90470
# Indexing 90471
# Indexing 90472
# Indexing 90473
# Indexing 90474
# Indexing 90475
# Indexing 90476
# Indexing 90477
# Indexing 90478
# Indexing 90479
# Indexing 90480
# Indexing 90481
# Indexing 90482
# Indexing 90483
# Indexing 90484
# Indexing 90485
# Indexing 90486
# Indexing 90487
# Indexing 90488
# Indexing 90489
# Indexing 90490
# Indexing 90491
# Indexing 90492
# Indexing 90493
# Indexing 90494
# Indexing 90495
# Indexing 90496
# Indexing 90497
# Indexing 90498
# Indexing 90499
# Indexing 90500
# Indexing 90501
# Indexing 90502
# Indexing 90503
# Indexing 90504
# Indexing 90505
# Indexing 90506
# Indexing 90507
# Indexing 90508
# Indexing 90509
# Indexing 90510
# Indexing 90511
# Indexing 90512
# Indexing 90513
# Indexing 90514
# Indexing 90515
# Indexing 90516
# Indexing 90517
# Indexing 90518
# Indexing 90519
# Indexing 90520
# Indexing 90521
# Indexing 90522
# Indexing 90523
# Indexing 90524
# Indexing 90525
# Indexing 90526
# Indexing 90527
# Indexing 90528
# Indexing 90529
# Indexing 90530
# Indexing 90531
# Indexing 90532
# Indexing 90533
# Indexing 90534
# Indexing 90535
# Indexing 90536
# Indexing 90537
# Indexing 90538
# Indexing 90539
# Indexing 90540
# Indexing 90541
# Indexing 90542
# Indexing 90543
# Indexing 90544
# Indexing 90545
# Indexing 90546
# Indexing 90547
# Indexing 90548
# Indexing 90549
# Indexing 90550
# Indexing 90551
# Indexing 90552
# Indexing 90553
# Indexing 90554
# Indexing 90555
# Indexing 90556
# Indexing 90557
# Indexing 90558
# Indexing 90559
# Indexing 90560
# Indexing 90561
# Indexing 90562
# Indexing 90563
# Indexing 90564
# Indexing 90565
# Indexing 90566
# Indexing 90567
# Indexing 90568
# Indexing 90569
# Indexing 90570
# Indexing 90571
# Indexing 90572
# Indexing 90573
# Indexing 90574
# Indexing 90575
# Indexing 90576
# Indexing 90577
# Indexing 90578
# Indexing 90579
# Indexing 90580
# Indexing 90581
# Indexing 90582
# Indexing 90583
# Indexing 90584
# Indexing 90585
# Indexing 90586
# Indexing 90587
# Indexing 90588
# Indexing 90589
# Indexing 90590
# Indexing 90591
# Indexing 90592
# Indexing 90593
# Indexing 90594
# Indexing 90595
# Indexing 90596
# Indexing 90597
# Indexing 90598
# Indexing 90599
# Indexing 90600
# Indexing 90601
# Indexing 90602
# Indexing 90603
# Indexing 90604
# Indexing 90605
# Indexing 90606
# Indexing 90607
# Indexing 90608
# Indexing 90609
# Indexing 90610
# Indexing 90611
# Indexing 90612
# Indexing 90613
# Indexing 90614
# Indexing 90615
# Indexing 90616
# Indexing 90617
# Indexing 90618
# Indexing 90619
# Indexing 90620
# Indexing 90621
# Indexing 90622
# Indexing 90623
# Indexing 90624
# Indexing 90625
# Indexing 90626
# Indexing 90627
# Indexing 90628
# Indexing 90629
# Indexing 90630
# Indexing 90631
# Indexing 90632
# Indexing 90633
# Indexing 90634
# Indexing 90635
# Indexing 90636
# Indexing 90637
# Indexing 90638
# Indexing 90639
# Indexing 90640
# Indexing 90641
# Indexing 90642
# Indexing 90643
# Indexing 90644
# Indexing 90645
# Indexing 90646
# Indexing 90647
# Indexing 90648
# Indexing 90649
# Indexing 90650
# Indexing 90651
# Indexing 90652
# Indexing 90653
# Indexing 90654
# Indexing 90655
# Indexing 90656
# Indexing 90657
# Indexing 90658
# Indexing 90659
# Indexing 90660
# Indexing 90661
# Indexing 90662
# Indexing 90663
# Indexing 90664
# Indexing 90665
# Indexing 90666
# Indexing 90667
# Indexing 90668
# Indexing 90669
# Indexing 90670
# Indexing 90671
# Indexing 90672
# Indexing 90673
# Indexing 90674
# Indexing 90675
# Indexing 90676
# Indexing 90677
# Indexing 90678
# Indexing 90679
# Indexing 90680
# Indexing 90681
# Indexing 90682
# Indexing 90683
# Indexing 90684
# Indexing 90685
# Indexing 90686
# Indexing 90687
# Indexing 90688
# Indexing 90689
# Indexing 90690
# Indexing 90691
# Indexing 90692
# Indexing 90693
# Indexing 90694
# Indexing 90695
# Indexing 90696
# Indexing 90697
# Indexing 90698
# Indexing 90699
# Indexing 90700
# Indexing 90701
# Indexing 90702
# Indexing 90703
# Indexing 90704
# Indexing 90705
# Indexing 90706
# Indexing 90707
# Indexing 90708
# Indexing 90709
# Indexing 90710
# Indexing 90711
# Indexing 90712
# Indexing 90713
# Indexing 90714
# Indexing 90715
# Indexing 90716
# Indexing 90717
# Indexing 90718
# Indexing 90719
# Indexing 90720
# Indexing 90721
# Indexing 90722
# Indexing 90723
# Indexing 90724
# Indexing 90725
# Indexing 90726
# Indexing 90727
# Indexing 90728
# Indexing 90729
# Indexing 90730
# Indexing 90731
# Indexing 90732
# Indexing 90733
# Indexing 90734
# Indexing 90735
# Indexing 90736
# Indexing 90737
# Indexing 90738
# Indexing 90739
# Indexing 90740
# Indexing 90741
# Indexing 90742
# Indexing 90743
# Indexing 90744
# Indexing 90745
# Indexing 90746
# Indexing 90747
# Indexing 90748
# Indexing 90749
# Indexing 90750
# Indexing 90751
# Indexing 90752
# Indexing 90753
# Indexing 90754
# Indexing 90755
# Indexing 90756
# Indexing 90757
# Indexing 90758
# Indexing 90759
# Indexing 90760
# Indexing 90761
# Indexing 90762
# Indexing 90763
# Indexing 90764
# Indexing 90765
# Indexing 90766
# Indexing 90767
# Indexing 90768
# Indexing 90769
# Indexing 90770
# Indexing 90771
# Indexing 90772
# Indexing 90773
# Indexing 90774
# Indexing 90775
# Indexing 90776
# Indexing 90777
# Indexing 90778
# Indexing 90779
# Indexing 90780
# Indexing 90781
# Indexing 90782
# Indexing 90783
# Indexing 90784
# Indexing 90785
# Indexing 90786
# Indexing 90787
# Indexing 90788
# Indexing 90789
# Indexing 90790
# Indexing 90791
# Indexing 90792
# Indexing 90793
# Indexing 90794
# Indexing 90795
# Indexing 90796
# Indexing 90797
# Indexing 90798
# Indexing 90799
# Indexing 90800
# Indexing 90801
# Indexing 90802
# Indexing 90803
# Indexing 90804
# Indexing 90805
# Indexing 90806
# Indexing 90807
# Indexing 90808
# Indexing 90809
# Indexing 90810
# Indexing 90811
# Indexing 90812
# Indexing 90813
# Indexing 90814
# Indexing 90815
# Indexing 90816
# Indexing 90817
# Indexing 90818
# Indexing 90819
# Indexing 90820
# Indexing 90821
# Indexing 90822
# Indexing 90823
# Indexing 90824
# Indexing 90825
# Indexing 90826
# Indexing 90827
# Indexing 90828
# Indexing 90829
# Indexing 90830
# Indexing 90831
# Indexing 90832
# Indexing 90833
# Indexing 90834
# Indexing 90835
# Indexing 90836
# Indexing 90837
# Indexing 90838
# Indexing 90839
# Indexing 90840
# Indexing 90841
# Indexing 90842
# Indexing 90843
# Indexing 90844
# Indexing 90845
# Indexing 90846
# Indexing 90847
# Indexing 90848
# Indexing 90849
# Indexing 90850
# Indexing 90851
# Indexing 90852
# Indexing 90853
# Indexing 90854
# Indexing 90855
# Indexing 90856
# Indexing 90857
# Indexing 90858
# Indexing 90859
# Indexing 90860
# Indexing 90861
# Indexing 90862
# Indexing 90863
# Indexing 90864
# Indexing 90865
# Indexing 90866
# Indexing 90867
# Indexing 90868
# Indexing 90869
# Indexing 90870
# Indexing 90871
# Indexing 90872
# Indexing 90873
# Indexing 90874
# Indexing 90875
# Indexing 90876
# Indexing 90877
# Indexing 90878
# Indexing 90879
# Indexing 90880
# Indexing 90881
# Indexing 90882
# Indexing 90883
# Indexing 90884
# Indexing 90885
# Indexing 90886
# Indexing 90887
# Indexing 90888
# Indexing 90889
# Indexing 90890
# Indexing 90891
# Indexing 90892
# Indexing 90893
# Indexing 90894
# Indexing 90895
# Indexing 90896
# Indexing 90897
# Indexing 90898
# Indexing 90899
# Indexing 90900
# Indexing 90901
# Indexing 90902
# Indexing 90903
# Indexing 90904
# Indexing 90905
# Indexing 90906
# Indexing 90907
# Indexing 90908
# Indexing 90909
# Indexing 90910
# Indexing 90911
# Indexing 90912
# Indexing 90913
# Indexing 90914
# Indexing 90915
# Indexing 90916
# Indexing 90917
# Indexing 90918
# Indexing 90919
# Indexing 90920
# Indexing 90921
# Indexing 90922
# Indexing 90923
# Indexing 90924
# Indexing 90925
# Indexing 90926
# Indexing 90927
# Indexing 90928
# Indexing 90929
# Indexing 90930
# Indexing 90931
# Indexing 90932
# Indexing 90933
# Indexing 90934
# Indexing 90935
# Indexing 90936
# Indexing 90937
# Indexing 90938
# Indexing 90939
# Indexing 90940
# Indexing 90941
# Indexing 90942
# Indexing 90943
# Indexing 90944
# Indexing 90945
# Indexing 90946
# Indexing 90947
# Indexing 90948
# Indexing 90949
# Indexing 90950
# Indexing 90951
# Indexing 90952
# Indexing 90953
# Indexing 90954
# Indexing 90955
# Indexing 90956
# Indexing 90957
# Indexing 90958
# Indexing 90959
# Indexing 90960
# Indexing 90961
# Indexing 90962
# Indexing 90963
# Indexing 90964
# Indexing 90965
# Indexing 90966
# Indexing 90967
# Indexing 90968
# Indexing 90969
# Indexing 90970
# Indexing 90971
# Indexing 90972
# Indexing 90973
# Indexing 90974
# Indexing 90975
# Indexing 90976
# Indexing 90977
# Indexing 90978
# Indexing 90979
# Indexing 90980
# Indexing 90981
# Indexing 90982
# Indexing 90983
# Indexing 90984
# Indexing 90985
# Indexing 90986
# Indexing 90987
# Indexing 90988
# Indexing 90989
# Indexing 90990
# Indexing 90991
# Indexing 90992
# Indexing 90993
# Indexing 90994
# Indexing 90995
# Indexing 90996
# Indexing 90997
# Indexing 90998
# Indexing 90999
# Indexing 91000
# Indexing 91001
# Indexing 91002
# Indexing 91003
# Indexing 91004
# Indexing 91005
# Indexing 91006
# Indexing 91007
# Indexing 91008
# Indexing 91009
# Indexing 91010
# Indexing 91011
# Indexing 91012
# Indexing 91013
# Indexing 91014
# Indexing 91015
# Indexing 91016
# Indexing 91017
# Indexing 91018
# Indexing 91019
# Indexing 91020
# Indexing 91021
# Indexing 91022
# Indexing 91023
# Indexing 91024
# Indexing 91025
# Indexing 91026
# Indexing 91027
# Indexing 91028
# Indexing 91029
# Indexing 91030
# Indexing 91031
# Indexing 91032
# Indexing 91033
# Indexing 91034
# Indexing 91035
# Indexing 91036
# Indexing 91037
# Indexing 91038
# Indexing 91039
# Indexing 91040
# Indexing 91041
# Indexing 91042
# Indexing 91043
# Indexing 91044
# Indexing 91045
# Indexing 91046
# Indexing 91047
# Indexing 91048
# Indexing 91049
# Indexing 91050
# Indexing 91051
# Indexing 91052
# Indexing 91053
# Indexing 91054
# Indexing 91055
# Indexing 91056
# Indexing 91057
# Indexing 91058
# Indexing 91059
# Indexing 91060
# Indexing 91061
# Indexing 91062
# Indexing 91063
# Indexing 91064
# Indexing 91065
# Indexing 91066
# Indexing 91067
# Indexing 91068
# Indexing 91069
# Indexing 91070
# Indexing 91071
# Indexing 91072
# Indexing 91073
# Indexing 91074
# Indexing 91075
# Indexing 91076
# Indexing 91077
# Indexing 91078
# Indexing 91079
# Indexing 91080
# Indexing 91081
# Indexing 91082
# Indexing 91083
# Indexing 91084
# Indexing 91085
# Indexing 91086
# Indexing 91087
# Indexing 91088
# Indexing 91089
# Indexing 91090
# Indexing 91091
# Indexing 91092
# Indexing 91093
# Indexing 91094
# Indexing 91095
# Indexing 91096
# Indexing 91097
# Indexing 91098
# Indexing 91099
# Indexing 91100
# Indexing 91101
# Indexing 91102
# Indexing 91103
# Indexing 91104
# Indexing 91105
# Indexing 91106
# Indexing 91107
# Indexing 91108
# Indexing 91109
# Indexing 91110
# Indexing 91111
# Indexing 91112
# Indexing 91113
# Indexing 91114
# Indexing 91115
# Indexing 91116
# Indexing 91117
# Indexing 91118
# Indexing 91119
# Indexing 91120
# Indexing 91121
# Indexing 91122
# Indexing 91123
# Indexing 91124
# Indexing 91125
# Indexing 91126
# Indexing 91127
# Indexing 91128
# Indexing 91129
# Indexing 91130
# Indexing 91131
# Indexing 91132
# Indexing 91133
# Indexing 91134
# Indexing 91135
# Indexing 91136
# Indexing 91137
# Indexing 91138
# Indexing 91139
# Indexing 91140
# Indexing 91141
# Indexing 91142
# Indexing 91143
# Indexing 91144
# Indexing 91145
# Indexing 91146
# Indexing 91147
# Indexing 91148
# Indexing 91149
# Indexing 91150
# Indexing 91151
# Indexing 91152
# Indexing 91153
# Indexing 91154
# Indexing 91155
# Indexing 91156
# Indexing 91157
# Indexing 91158
# Indexing 91159
# Indexing 91160
# Indexing 91161
# Indexing 91162
# Indexing 91163
# Indexing 91164
# Indexing 91165
# Indexing 91166
# Indexing 91167
# Indexing 91168
# Indexing 91169
# Indexing 91170
# Indexing 91171
# Indexing 91172
# Indexing 91173
# Indexing 91174
# Indexing 91175
# Indexing 91176
# Indexing 91177
# Indexing 91178
# Indexing 91179
# Indexing 91180
# Indexing 91181
# Indexing 91182
# Indexing 91183
# Indexing 91184
# Indexing 91185
# Indexing 91186
# Indexing 91187
# Indexing 91188
# Indexing 91189
# Indexing 91190
# Indexing 91191
# Indexing 91192
# Indexing 91193
# Indexing 91194
# Indexing 91195
# Indexing 91196
# Indexing 91197
# Indexing 91198
# Indexing 91199
# Indexing 91200
# Indexing 91201
# Indexing 91202
# Indexing 91203
# Indexing 91204
# Indexing 91205
# Indexing 91206
# Indexing 91207
# Indexing 91208
# Indexing 91209
# Indexing 91210
# Indexing 91211
# Indexing 91212
# Indexing 91213
# Indexing 91214
# Indexing 91215
# Indexing 91216
# Indexing 91217
# Indexing 91218
# Indexing 91219
# Indexing 91220
# Indexing 91221
# Indexing 91222
# Indexing 91223
# Indexing 91224
# Indexing 91225
# Indexing 91226
# Indexing 91227
# Indexing 91228
# Indexing 91229
# Indexing 91230
# Indexing 91231
# Indexing 91232
# Indexing 91233
# Indexing 91234
# Indexing 91235
# Indexing 91236
# Indexing 91237
# Indexing 91238
# Indexing 91239
# Indexing 91240
# Indexing 91241
# Indexing 91242
# Indexing 91243
# Indexing 91244
# Indexing 91245
# Indexing 91246
# Indexing 91247
# Indexing 91248
# Indexing 91249
# Indexing 91250
# Indexing 91251
# Indexing 91252
# Indexing 91253
# Indexing 91254
# Indexing 91255
# Indexing 91256
# Indexing 91257
# Indexing 91258
# Indexing 91259
# Indexing 91260
# Indexing 91261
# Indexing 91262
# Indexing 91263
# Indexing 91264
# Indexing 91265
# Indexing 91266
# Indexing 91267
# Indexing 91268
# Indexing 91269
# Indexing 91270
# Indexing 91271
# Indexing 91272
# Indexing 91273
# Indexing 91274
# Indexing 91275
# Indexing 91276
# Indexing 91277
# Indexing 91278
# Indexing 91279
# Indexing 91280
# Indexing 91281
# Indexing 91282
# Indexing 91283
# Indexing 91284
# Indexing 91285
# Indexing 91286
# Indexing 91287
# Indexing 91288
# Indexing 91289
# Indexing 91290
# Indexing 91291
# Indexing 91292
# Indexing 91293
# Indexing 91294
# Indexing 91295
# Indexing 91296
# Indexing 91297
# Indexing 91298
# Indexing 91299
# Indexing 91300
# Indexing 91301
# Indexing 91302
# Indexing 91303
# Indexing 91304
# Indexing 91305
# Indexing 91306
# Indexing 91307
# Indexing 91308
# Indexing 91309
# Indexing 91310
# Indexing 91311
# Indexing 91312
# Indexing 91313
# Indexing 91314
# Indexing 91315
# Indexing 91316
# Indexing 91317
# Indexing 91318
# Indexing 91319
# Indexing 91320
# Indexing 91321
# Indexing 91322
# Indexing 91323
# Indexing 91324
# Indexing 91325
# Indexing 91326
# Indexing 91327
# Indexing 91328
# Indexing 91329
# Indexing 91330
# Indexing 91331
# Indexing 91332
# Indexing 91333
# Indexing 91334
# Indexing 91335
# Indexing 91336
# Indexing 91337
# Indexing 91338
# Indexing 91339
# Indexing 91340
# Indexing 91341
# Indexing 91342
# Indexing 91343
# Indexing 91344
# Indexing 91345
# Indexing 91346
# Indexing 91347
# Indexing 91348
# Indexing 91349
# Indexing 91350
# Indexing 91351
# Indexing 91352
# Indexing 91353
# Indexing 91354
# Indexing 91355
# Indexing 91356
# Indexing 91357
# Indexing 91358
# Indexing 91359
# Indexing 91360
# Indexing 91361
# Indexing 91362
# Indexing 91363
# Indexing 91364
# Indexing 91365
# Indexing 91366
# Indexing 91367
# Indexing 91368
# Indexing 91369
# Indexing 91370
# Indexing 91371
# Indexing 91372
# Indexing 91373
# Indexing 91374
# Indexing 91375
# Indexing 91376
# Indexing 91377
# Indexing 91378
# Indexing 91379
# Indexing 91380
# Indexing 91381
# Indexing 91382
# Indexing 91383
# Indexing 91384
# Indexing 91385
# Indexing 91386
# Indexing 91387
# Indexing 91388
# Indexing 91389
# Indexing 91390
# Indexing 91391
# Indexing 91392
# Indexing 91393
# Indexing 91394
# Indexing 91395
# Indexing 91396
# Indexing 91397
# Indexing 91398
# Indexing 91399
# Indexing 91400
# Indexing 91401
# Indexing 91402
# Indexing 91403
# Indexing 91404
# Indexing 91405
# Indexing 91406
# Indexing 91407
# Indexing 91408
# Indexing 91409
# Indexing 91410
# Indexing 91411
# Indexing 91412
# Indexing 91413
# Indexing 91414
# Indexing 91415
# Indexing 91416
# Indexing 91417
# Indexing 91418
# Indexing 91419
# Indexing 91420
# Indexing 91421
# Indexing 91422
# Indexing 91423
# Indexing 91424
# Indexing 91425
# Indexing 91426
# Indexing 91427
# Indexing 91428
# Indexing 91429
# Indexing 91430
# Indexing 91431
# Indexing 91432
# Indexing 91433
# Indexing 91434
# Indexing 91435
# Indexing 91436
# Indexing 91437
# Indexing 91438
# Indexing 91439
# Indexing 91440
# Indexing 91441
# Indexing 91442
# Indexing 91443
# Indexing 91444
# Indexing 91445
# Indexing 91446
# Indexing 91447
# Indexing 91448
# Indexing 91449
# Indexing 91450
# Indexing 91451
# Indexing 91452
# Indexing 91453
# Indexing 91454
# Indexing 91455
# Indexing 91456
# Indexing 91457
# Indexing 91458
# Indexing 91459
# Indexing 91460
# Indexing 91461
# Indexing 91462
# Indexing 91463
# Indexing 91464
# Indexing 91465
# Indexing 91466
# Indexing 91467
# Indexing 91468
# Indexing 91469
# Indexing 91470
# Indexing 91471
# Indexing 91472
# Indexing 91473
# Indexing 91474
# Indexing 91475
# Indexing 91476
# Indexing 91477
# Indexing 91478
# Indexing 91479
# Indexing 91480
# Indexing 91481
# Indexing 91482
# Indexing 91483
# Indexing 91484
# Indexing 91485
# Indexing 91486
# Indexing 91487
# Indexing 91488
# Indexing 91489
# Indexing 91490
# Indexing complete.
# ((1491, 512), dtype('float64'))

# %% [markdown]
# ## 5. Setup a nearest neighbors search structure
# We will use a simple nearest neighbors implementatio to test our approach.

# %%
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Using scikit-learn's implementation of nearest neighbors, setup a search engine with a linear search strategy and an appropriate metric.**
# </div>

# %%
print(global_image_descr.shape)
search_engine = NearestNeighbors(algorithm='brute', metric='cosine').fit(global_image_descr)
# Out:
# (1491, 512)

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Now index you descriptors.**
# </div>

# %%
# index descriptors

# %% [markdown]
# ## 6. Evaluate our approach using mean average precision
# We can now evaluate the performance of our search engine using the available ground truth.
#
# ### 6.1 Load the ground truth
# The ground truth is a simple dictionary mapping query ids to relevant image ids:
# ```json
# {'90314': ['90989', '91259'],
#  '90376': ['90674'],
#  '90175': ['90512'],
#  ...
# }
# ```

# %%
import json
PATH_TO_GT = os.path.join(PATH_TO_RESOURCES, "gt_student.json")
gt_data = None
with open(PATH_TO_GT, 'r') as in_gt:
    gt_data = json.load(in_gt)
#print(gt_data)
# Out:
# {'90314': ['90989', '91259'], '90376': ['90674'], '90175': ['90512'], '90949': ['90123', '91149'], '90818': ['91297'], '91374': ['91423', '91344', '90860'], '90696': ['90606'], '90464': ['91331'], '90413': ['90409'], '90356': ['90923', '90968'], '90185': ['90890'], '90284': ['91195'], '90341': ['90758'], '90783': ['91222'], '90529': ['90360', '90410', '91027', '90141'], '90721': ['90565', '90370', '90092', '90695'], '91298': ['90792'], '91437': ['90470', '90330'], '90153': ['90964'], '90581': ['90733'], '90439': ['91395'], '90841': ['91369'], '91069': ['90166', '91266'], '90766': ['91047', '90033', '91227'], '90359': ['90960', '90907'], '90081': ['90506'], '90126': ['90793'], '90531': ['90164'], '90503': ['91113', '90430'], '90093': ['90104'], '90222': ['90928', '90095'], '90977': ['90922', '90609'], '90180': ['91388', '90338', '91200', '91309'], '91246': ['90919', '90701', '90525', '90608'], '90690': ['90226'], '90669': ['91157',
#
# The upside is that reusing the precomputed descriptors avoids us the need for computing the BoVW vector for each query image.
#
# We use the `imgid_to_index`, which helps us converting between image ids (filename without directory nor extension) and index value in the `global_image_descr` array, to recover the indices of the rows corresponding to the query images in `global_image_descr`.
#
# Here is below some code you should run and try to understand.

# %%
# get the indices of the query images
query_imnos = [imgid_to_index[query_id] for query_id in gt_data.keys()]
#imgid_to_index
#query_imnos
#IMG_IDS[query_imnos[0]]
#gt_data[IMG_IDS[query_imnos[0]]]

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Using `query_imnos`, you can now select the descriptors of the query images.**
# </div>

# %%
# select the descriptors of the query images
query_vectors = global_image_descr[query_imnos].reshape(len(query_imnos),512)
query_vectors.size
# Out:
# 128000

# %% [markdown]
# ### 6.4 Run the query

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Run a search query for all query images using our search engine. Ask for 9 neighbors because we want 8 real results and we will later remove the query from the list of results.**
# </div>

# %%
# get the 9 (8 real) NNs for all query images
distances, results = search_engine.kneighbors(query_vectors, n_neighbors = 9, return_distance=True)
distances.shape, results.shape

# f = np.vectorize(lambda ii:IMG_IDS[ii])
# np.apply_along_axis(lambda t: f(t) , 1, results)
# Out:
# ((250, 9), (250, 9))

# %% [markdown]
# We expect here a shape of `(250, 9)` for the results.

# %% [markdown]
# ### 6.4 Evaluate the performance using mAP
# The mean average precision is the mean of the AP computed for each query.
# The AP is the area under the precision-recall curve.
#
# For each query, we will therefore sum the areas of the trapezoids between each recall values.

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Complete the code below to compute the mean average precision of our search engine on the training set.**
# </div>

# %%
aps = []  # list of average precisions for all queries
for qimno, qres in zip(query_imnos, results):
    qname = IMG_IDS[qimno]
    # print("query:", qname)
    # collect the positive results in the dataset
    # the positives have the same prefix as the query image
    positive_results = [imgid_to_index[img_id] for img_id in gt_data[IMG_IDS[qimno]]]
    # print("positive_results:", positive_results)
    # print("qres:", qres)
    # ranks of positives. We skip the result #0, assumed to be the query image
    ranks = [i for i, res in enumerate(qres[1:]) if res in positive_results]
    # print("ranks:", ranks)
    # accumulate trapezoids with this basis
    recall_step = 1.0 / len(positive_results)
    ap = 0
    for ntp, rank in enumerate(ranks):
        # ntp = nb of true positives so far
        # rank = nb of retrieved items so far
        # y-size on left side of trapezoid:
        precision_0 = ntp/float(rank) if rank > 0 else 1.0
        # y-size on right side of trapezoid:
        precision_1 = (ntp + 1) / float(rank + 1)
        ap += (precision_1 + precision_0) * recall_step / 2.0
        # print("query %s, AP = %.3f" % (qname, ap))
    aps.append(ap)

print("mean AP = %.3f" % np.mean(aps))
# Out:
# mean AP = 0.401

# %% [markdown]
# ## 7. Display some results
# We provide you with some code to display query results.

# %%
from matplotlib import pyplot as plt
from matplotlib.image import imread

nrow = 8   # number of query images to show
nres = 8   # number of results per query

def show_image(imno, frame_color):
    im = imread(os.path.join(PATH_TO_RESOURCES, "thumbs", "%s.jpg" % IMG_IDS[imno]))
    plt.imshow(im)
    h, w = im.shape[:2]
    plt.plot([0, 0, w, w, 0], [0, h, h, 0, 0], frame_color, linewidth = 2)
    plt.axis('off')

# reduce the margins
plt.subplots_adjust(wspace = 0, hspace = 0,
                    top = 0.99, bottom = 0.01, left = 0.01, right = 0.99)

plt.figure(figsize=(16,10))
no = 1  # index current of subfigure
for qno in range(nrow):
    plt.subplot(nrow, nres + 1, no); no += 1
    # show query image with white outline
    qimno = query_imnos[qno]
    show_image(qimno, 'w')
    plt.title(IMG_IDS[qimno])
    for res_rank, qres in enumerate(results[qno, 1:nres+1]): # 1:nres+1 => skip query from results
        plt.subplot(nrow, nres + 1, no); no += 1
        # use image name to determine if it is a TP or FP result
        is_ok = IMG_IDS[qres] in gt_data[IMG_IDS[qimno]]
        show_image(qres, 'g' if is_ok else 'r')
        # plt.title("%0.2f" % (distances[qno,res_rank]))
        plt.title(IMG_IDS[qres])

plt.show()

# %% [markdown]
# ## 8. Compute the best results for the test queries
# You are now ready to process the test data for the grading.
#
# We provide you with a set of query ids, and you must produce the list of most releveant results for each.

# %%
test_queries = None
with open(os.path.join(PATH_TO_RESOURCES, "queries_for_grading.json")) as qin:
    test_queries = json.load(qin)
test_queries[:10]
# Out:
# ['91401',
#  '91274',
#  '90136',
#  '91071',
#  '91221',
#  '90274',
#  '90240',
#  '90662',
#  '90169',
#  '90751']

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **For each query, compute the list of best results.**
# </div>

# %%
test_queries_imnos = [imgid_to_index[query_id] for query_id in test_queries]
test_query_vectors = global_image_descr[test_queries_imnos].reshape(len(test_queries_imnos), 512)
distances, results = search_engine.kneighbors(test_query_vectors, n_neighbors = 9, return_distance=True)

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Display your results to control them visually.**
# </div>

# %%
from matplotlib import pyplot as plt
from matplotlib.image import imread

nrow = 8   # number of query images to show
nres = 8   # number of results per query

def show_image(imno, frame_color):
    im = imread(os.path.join(PATH_TO_RESOURCES, "thumbs", "%s.jpg" % IMG_IDS[imno]))
    plt.imshow(im)
    h, w = im.shape[:2]
    plt.plot([0, 0, w, w, 0], [0, h, h, 0, 0], frame_color, linewidth = 2)
    plt.axis('off')

# reduce the margins
plt.subplots_adjust(wspace = 0, hspace = 0,
                    top = 0.99, bottom = 0.01, left = 0.01, right = 0.99)

plt.figure(figsize=(16,10))
no = 1  # index current of subfigure
for qno in range(nrow):
    plt.subplot(nrow, nres + 1, no); no += 1
    # show query image with white outline
    qimno = test_queries_imnos[qno]
    show_image(qimno, 'w')
    plt.title(IMG_IDS[qimno])
    #1:nres+1
    for res_rank, qres in enumerate(results[qno, 0:nres]): # 1:nres+1 => skip query from results
        plt.subplot(nrow, nres + 1, no); no += 1
        # use image name to determine if it is a TP or FP result
        #is_ok = IMG_IDS[qres] in gt_data[IMG_IDS[qimno]]
        show_image(qres, 'w')
        # plt.title("%0.2f" % (distances[qno,res_rank]))
        plt.title(IMG_IDS[qres])

plt.show()

# %% [markdown]
# ## 9. Export the results for the test queries
#
# Here is some code to export your results in the appropriate format.
#
# **Do not forget to submit them!**

# %%
results = {query_id: [IMG_IDS[ri] for ri in results_ids[1:]]
           for query_id,results_ids in zip(test_queries, results)}
results

# %%
EXPORT_PATH = "results.json"

# %%
with open(EXPORT_PATH, 'w') as outres:
    json.dump(results, outres, indent=1)
# !head $EXPORT_PATH

# %% [markdown]
# # Job done!
# Do you think you can improve the performance of your approach and get a better grading?
